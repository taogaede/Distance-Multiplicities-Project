# %%
from sage.graphs.distances_all_pairs import floyd_warshall
from sage.graphs.distances_all_pairs import diameter

def allRarySequences(length, alphSize):  #Finds all r-ary sequences of length numEdges.  Used for weight assignments.
    DBSeq = DeBruijnSequences(alphSize,length).an_element()
    #print(DBSeq)
    rArySequences = []
    for i in range(0,len(DBSeq)):
        currentSeq = []
        for j in range(0,length):
            index = (i + j) % (len(DBSeq))
            currentSeq.append(DBSeq[index]+1)
        rArySequences.append(currentSeq)
    return rArySequences

def calculateMultiplicityList(dist):
    Mult = []
    for i in range(1,n):
        ithMult = 0
        for j in range(0,n):
            for k in range(j+1,n):
                if dist[j][k] == i:
                    ithMult = ithMult + 1
        Mult.append(ithMult)
    return Mult

def checkCCCondition(Mult):
    isCC = true
    for i in range(1,n):
        if i not in Mult:
            isCC = false
    return isCC

def checkUniformMultiplicityCondition(Mult):
    n = len(Mult)+1
    isUniform = true
    for i in Mult:
        if i != floor(n/2):
            isUniform = false
    return isUniform
    

n = 7  #number of vertices (Remember to also change numVertices in the "nauty_geng" argument)
e = 6  #number of edges (Remember to also change numEdges in the "nauty_geng" argument)
r = 6  #weights are chosen in {1,2,...,r}.  Note r must be at least 2 for the DeBruijn method above to work.
n argument: ("numVertices numEdges:numEdges -c").  "-c" restricts to connected graphs.
rArySequences = allRarySequences(e,r) #Makes all r-ary sequences (+1 to each entry) usGraphs = graphs.nauty_geng("7 6:6 -c") #Generates all connected graphs on specified numVertices and numEdges ***Must input actual value of vertices and edges iing DeBruijn sequence method above.
#print(rArySequences)
if r == 1:
    allOnes = [1 for i in range(e)]
    rArySequences.append(allOnes)
numberNonSols = 0
totalCCGWeightings = 0.0
averageMultiplicities = [0.0 for i in range(n-1)]
numberOfGraphs = 0
for G in Graphs:
    numberOfGraphs += 1
    aveMultsForG = [0.0 for i in range(n-1)]
    sizeOfAutomorphismGroup = G.automorphism_group().cardinality() #Size of symmetry group of G
    if sizeOfAutomorphismGroup >= 1:
        numberOfWorkingWeightAssignments = 0 #Counts number of weight assignments that make G a CCG
        for weightAssignment in rArySequences:
            
            #to make searching for non-solutions more efficient
            #if numberOfWorkingWeightAssignments >0:
                #break
            
            #I couldn't find a good weighted graph distance package, so I just subdivided edges in G a number of times equal to the edge weight.  I think this approach is not too inefficient.
            #Edge weight assignment
            H = G.copy()
            edgeCounter = 0
            for u in range(0,n):
                for v in range(u+1,n):
                    if G.has_edge(u,v):
                        #print(edgeCounter)
                        if r>1:
                            H.subdivide_edge((u,v),weightAssignment[edgeCounter]-1)
                        G.set_edge_label(u,v,weightAssignment[edgeCounter])
                        edgeCounter = edgeCounter+1
            if sage.graphs.distances_all_pairs.diameter(H, algorithm='2sweep', source=None) <= n-1:
                #Calculating distances
                dist = floyd_warshall(H, paths=false, distances=true)
                #Calculating Multiplicity List
                Mult = calculateMultiplicityList(dist)

                #Option 1: Checking whether distances satisfy CC condition
                #If weight assignment works on G, then print relevant info and show weighted graph.
                
                if checkCCCondition(Mult) == true:
                    #G.show(vertex_labels=True, edge_labels=True, graph_border=True, figsize=[4,4])
                    for b in range(1,n):
                        aveMultsForG[b-1] += Mult[b-1]
                    print("Multiplicity list:", Mult)
                    numberOfWorkingWeightAssignments = numberOfWorkingWeightAssignments+1

                #Option 2: Checks for Uniform Multiplicity Property
                #if checkUniformMultiplicityCondition(Mult) == true:
                    #G.show(vertex_labels=True, edge_labels=True, graph_border=True, figsize=[4,4])
                    #print("Multiplicity list:", Mult)
                    #numberOfWorkingWeightAssignments = numberOfWorkingWeightAssignments+1

        #If no weight assignment works, then just print the graph without edge weights.
        if numberOfWorkingWeightAssignments == 0:
            G.show(vertex_labels=True, edge_labels=False, graph_border=True, figsize=[4,4])
            numberNonSols +=1
        if numberOfWorkingWeightAssignments > 0:
            for b in range(1,n):
                aveMultsForG[b-1] = round(aveMultsForG[b-1]/numberOfWorkingWeightAssignments,2)
                averageMultiplicities[b-1] += aveMultsForG[b-1]
        print("( Number of Weight Assignments, Size of Automorphism Group ) = (",numberOfWorkingWeightAssignments, sizeOfAutomorphismGroup,")")
for b in range(1,n):
    averageMultiplicities[b-1] = round(averageMultiplicities[b-1]/(numberOfGraphs-numberNonSols),2)
print(averageMultiplicities)
print("Number of Non-Solutions: ",  numberNonSols)
# Out:
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [3, 4, 5, 6, 2, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [2, 3, 6, 5, 4, 1]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# Multiplicity list: [1, 2, 5, 4, 6, 3]
# ( Number of Weight Assignments, Size of Automorphism Group ) = ( 210 720 )
# Multiplicity list: [2, 3, 4, 5, 6, 1]
# Multiplicity list: [2, 3, 4, 5, 6, 1]
# Multiplicity list: [2, 3, 4, 5, 6, 1]
# Multiplicity list: [2, 1, 5, 4, 3, 6]
# Multiplicity list: [2, 3, 4, 5, 6, 1]
# Multiplicity list: [2, 3, 4, 5, 6, 1]
# Multiplicity list: [2, 3, 4, 5, 6, 1]
# Multiplicity list: [2, 1, 5, 4, 3, 6]
# Multiplicity list: [2, 1, 5, 4, 3, 6]
# Multiplicity list: [2, 1, 5, 4, 3, 6]
# Multiplicity list: [1, 2, 5, 3, 4, 6]
# Multiplicity list: [1, 2, 5, 3, 4, 6]
# Multiplicity list: [1, 2, 5, 3, 4, 6]
# Multiplicity list: [1, 2, 5, 3, 4, 6]
# ( Number of Weight Assignments, Size of Automorphism Group ) = ( 14 24 )
# Multiplicity list: [5, 6, 1, 2, 4, 3]
# Multiplicity list: [3, 5, 6, 4, 1, 2]
# Multiplicity list: [3, 5, 6, 4, 1, 2]
# Multiplicity list: [3, 5, 6, 4, 1, 2]
# ( Number of Weight Assignments, Size of Automorphism Group ) = ( 4 6 )
# Multiplicity list: [5, 6, 4, 1, 3, 2]
# Multiplicity list: [5, 6, 4, 1, 3, 2]
# Multiplicity list: [5, 6, 4, 1, 3, 2]
# Multiplicity list: [4, 3, 5, 6, 1, 2]
# Multiplicity list: [4, 5, 6, 3, 2, 1]
# Multiplicity list: [4, 5, 6, 3, 2, 1]
# Multiplicity list: [3, 5, 2, 6, 1, 4]
# Multiplicity list: [3, 5, 2, 6, 1, 4]
# Multiplicity list: [4, 3, 5, 6, 1, 2]
# Multiplicity list: [4, 5, 6, 3, 2, 1]
# Multiplicity list: [4, 5, 6, 3, 2, 1]
# Multiplicity list: [3, 4, 6, 5, 1, 2]
# Multiplicity list: [3, 5, 1, 4, 2, 6]
# Multiplicity list: [3, 5, 2, 6, 1, 4]
# Multiplicity list: [4, 3, 5, 6, 1, 2]
# Multiplicity list: [4, 5, 6, 3, 2, 1]
# Multiplicity list: [4, 5, 6, 3, 2, 1]
# Multiplicity list: [3, 4, 6, 5, 1, 2]
# Multiplicity list: [2, 4, 1, 5, 3, 6]
# Multiplicity list: [2, 3, 4, 1, 6, 5]
# Multiplicity list: [3, 4, 6, 5, 1, 2]
# Multiplicity list: [3, 4, 6, 5, 1, 2]
# Multiplicity list: [3, 4, 6, 5, 1, 2]
# Multiplicity list: [2, 3, 4, 1, 6, 5]
# Multiplicity list: [2, 3, 4, 1, 6, 5]
# Multiplicity list: [3, 4, 6, 5, 1, 2]
# Multiplicity list: [1, 5, 3, 6, 2, 4]
# Multiplicity list: [1, 5, 3, 6, 2, 4]
# Multiplicity list: [1, 5, 3, 6, 2, 4]
# Multiplicity list: [1, 4, 5, 3, 6, 2]
# Multiplicity list: [1, 4, 5, 3, 6, 2]
# Multiplicity list: [1, 4, 5, 3, 6, 2]
# ( Number of Weight Assignments, Size of Automorphism Group ) = ( 32 12 )
# Multiplicity list: [4, 5, 6, 3, 2, 1]
# Multiplicity list: [4, 5, 6, 3, 2, 1]
# Multiplicity list: [4, 5, 6, 3, 2, 1]
# Multiplicity list: [4, 5, 6, 3, 2, 1]
# Multiplicity list: [3, 6, 1, 5, 2, 4]
# Multiplicity list: [3, 6, 1, 5, 2, 4]
# ( Number of Weight Assignments, Size of Automorphism Group ) = ( 6 8 )
# Multiplicity list: [4, 6, 5, 2, 3, 1]
# Multiplicity list: [4, 6, 5, 2, 3, 1]
# Multiplicity list: [4, 3, 6, 5, 2, 1]
# Multiplicity list: [3, 6, 5, 4, 2, 1]
# Multiplicity list: [3, 6, 5, 4, 2, 1]
# Multiplicity list: [2, 5, 6, 3, 4, 1]
# ( Number of Weight Assignments, Size of Automorphism Group ) = ( 6 4 )
# Multiplicity list: [5, 6, 4, 3, 1, 2]
# ( Number of Weight Assignments, Size of Automorphism Group ) = ( 1 2 )
# Graphics object consisting of 15 graphics primitives
# ( Number of Weight Assignments, Size of Automorphism Group ) = ( 0 1 )
# Graphics object consisting of 15 graphics primitives
# ( Number of Weight Assignments, Size of Automorphism Group ) = ( 0 2 )
# Graphics object consisting of 15 graphics primitives
# ( Number of Weight Assignments, Size of Automorphism Group ) = ( 0 6 )
# Multiplicity list: [6, 5, 4, 3, 2, 1]
# ( Number of Weight Assignments, Size of Automorphism Group ) = ( 1 2 )
# [3.52, 4.56, 4.61, 3.7, 2.56, 2.05]
# Number of Non-Solutions:  3
