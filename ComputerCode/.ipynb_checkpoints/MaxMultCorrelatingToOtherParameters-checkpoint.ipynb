# %%
from sage.plot.scatter_plot import ScatterPlot
n=10
trees = graphs.trees(n)
maxMultList = []
maxAdjEValList = []
maxLapEValList = []
maxDistEValList = []
maxDegreeList = []
aveDistanceList = []
aveDistanceDistanceList = []
maxMultDistancesList = []
for T in trees:
    Dist = T.distances_distribution()
    Mult = list(Dist.values())
    maxMult = max(Mult)*n*(n-1)/2
    oneMult = Dist[1]*n*(n-1)/2
    twoMult = Dist[2]*n*(n-1)/2
    #threeMult = Dist[3]*n*(n-1)/2
    if twoMult <= maxMult and maxMult >= 3:
        largestDistMaxMult = 0
        for d in range(1,len(Dist)+1):
            if Mult[d-1]*n*(n-1)/2 == maxMult:
                largestDistMaxMult = d
        maxMultDistancesList.append([maxMult,largestDistMaxMult])
        if largestDistMaxMult == ceil(n/3)-2:        
            AdjSpectrum = T.spectrum()
            LaplacianSpectrum = T.laplacian_matrix().eigenvalues()
            DistSpectrum = T.distance_matrix().eigenvalues()
            Degrees = T.degree_sequence()

            maxEValAdj = max(AdjSpectrum)
            maxEValLap = max(LaplacianSpectrum)
            maxEValDist = max(DistSpectrum)
            maxDegree = max(Degrees)
            aveDistance = T.average_distance()

            maxMultList.append(maxMult)

            maxDegreeList.append([maxMult,maxDegree])
            maxAdjEValList.append([maxMult,maxEValAdj])
            maxLapEValList.append([maxMult,maxEValLap])
            maxDistEValList.append([maxMult,maxEValDist])
            aveDistanceList.append([maxMult,aveDistance])
            aveDistanceDistanceList.append([aveDistance,maxEValDist])
            print(Mult)
            print(maxMult,largestDistMaxMult)
            show(T)
        
print("Max Adj Matrix EVal over Max Mult")
AdjPlot = scatter_plot(maxAdjEValList)
show(AdjPlot)
print("Max Lap Matrix EVal over Max Mult")
LapPlot = scatter_plot(maxLapEValList)
show(LapPlot)
print("Max Distance Matrix EVal over Max Mult")
DistPlot = scatter_plot(maxDistEValList)
show(DistPlot)
print("Max Degree over Max Mult")
DegreePlot = scatter_plot(maxDegreeList)
show(DegreePlot)
print("Average Distance over Max Mult")
aveDistancePlot = scatter_plot(aveDistanceList)
show(aveDistancePlot)
print("Average Distance over Max Distance Matrix EVal")
aveDistanceDistancePlot = scatter_plot(aveDistanceDistanceList)
show(aveDistanceDistancePlot)
print("Smallest Distance with Max Mult over Max Mult")
SmallestMostFreqDistPlot = scatter_plot(maxMultDistancesList)
show(SmallestMostFreqDistPlot)
# Out:
# [1/5, 1/5, 7/45, 2/15, 1/9, 4/45, 1/15, 2/45]
# 9 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 2/9, 7/45, 2/15, 1/9, 4/45, 4/45]
# 10 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 1/5, 8/45, 2/15, 1/9, 4/45, 1/15, 1/45]
# 9 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 2/9, 8/45, 2/15, 1/9, 1/9, 2/45]
# 10 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 2/9, 1/5, 2/15, 2/15, 4/45, 1/45]
# 10 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 1/5, 8/45, 7/45, 1/9, 4/45, 2/45, 1/45]
# 9 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 2/9, 8/45, 7/45, 2/15, 1/15, 2/45]
# 10 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 2/9, 1/5, 8/45, 1/9, 1/15, 1/45]
# 10 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 1/5, 8/45, 7/45, 2/15, 1/15, 2/45, 1/45]
# 9 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 11/45, 7/45, 2/15, 1/9, 4/45, 1/15]
# 11 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 2/9, 1/5, 2/15, 1/9, 4/45, 2/45]
# 10 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 2/9, 8/45, 8/45, 1/9, 1/15, 2/45]
# 10 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 11/45, 1/5, 2/15, 1/9, 4/45, 1/45]
# 11 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 11/45, 1/5, 8/45, 1/9, 2/45, 1/45]
# 11 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 14/45, 7/45, 2/15, 1/9, 4/45]
# 14 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 4/15, 2/9, 2/15, 1/9, 1/15]
# 12 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 4/15, 7/45, 2/15, 1/9, 2/15]
# 12 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 4/15, 8/45, 2/15, 7/45, 1/15]
# 12 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 4/15, 8/45, 1/5, 4/45, 1/15]
# 12 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 14/45, 7/45, 2/15, 1/5]
# 14 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 4/15, 11/45, 2/15, 1/9, 2/45]
# 12 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 11/45, 1/5, 2/15, 2/15, 4/45]
# 11 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 11/45, 2/9, 7/45, 2/15, 2/45]
# 11 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 13/45, 1/5, 8/45, 2/15]
# 13 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 11/45, 8/45, 1/5, 4/45, 4/45]
# 11 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 2/9, 1/5, 7/45, 2/15, 4/45]
# 10 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 4/15, 1/5, 2/15, 7/45, 2/45]
# 12 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 11/45, 2/9, 8/45, 1/9, 2/45]
# 11 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 2/9, 1/5, 1/5, 2/15, 2/45]
# 10 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 4/15, 1/5, 2/9, 1/15, 2/45]
# 12 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 1/3, 7/45, 2/15, 8/45]
# 15 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 13/45, 2/9, 7/45, 2/15]
# 13 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 11/45, 2/9, 1/5, 2/15]
# 11 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 13/45, 11/45, 8/45, 4/45]
# 13 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 4/15, 11/45, 1/5, 4/45]
# 12 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 1/3, 2/9, 1/5, 2/45]
# 15 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 4/15, 1/5, 1/5, 2/15]
# 12 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 14/45, 2/9, 2/15, 1/9, 1/45]
# 14 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 4/15, 2/9, 8/45, 1/9, 1/45]
# 12 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 14/45, 1/5, 2/9, 1/15]
# 14 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 1/3, 8/45, 1/5, 4/45]
# 15 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 13/45, 4/15, 8/45, 1/15]
# 13 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 1/3, 14/45, 2/15, 1/45]
# 15 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 14/45, 2/9, 1/5, 2/45, 1/45]
# 14 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 2/5, 7/45, 2/15, 1/9]
# 18 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 1/3, 11/45, 2/15, 4/45]
# 15 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 4/15, 11/45, 1/5, 4/45]
# 12 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 14/45, 13/45, 2/15, 1/15]
# 14 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 1/3, 13/45, 2/15, 2/45]
# 15 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 14/45, 13/45, 7/45, 2/45]
# 14 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 2/5, 11/45, 2/15, 1/45]
# 18 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 23/45, 7/45, 2/15]
# 23 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 19/45, 7/45, 2/9]
# 19 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 19/45, 4/15, 1/9]
# 19 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 17/45, 7/45, 4/15]
# 17 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 16/45, 4/15, 8/45]
# 16 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 1/3, 4/15, 1/5]
# 15 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 17/45, 1/3, 4/45]
# 17 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 4/9, 16/45]
# 20 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 1/3, 4/15, 1/5]
# 15 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 13/45, 4/15, 11/45]
# 13 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 17/45, 16/45, 1/15]
# 17 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 7/15, 1/3]
# 21 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 19/45, 1/3, 2/45]
# 19 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 8/15, 4/15]
# 24 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 2/5, 1/3, 1/15]
# 18 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 23/45, 4/15, 1/45]
# 23 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 29/45, 7/45]
# 29 2
# Graphics object consisting of 20 graphics primitives
# [1/5, 4/5]
# 36 2
# Graphics object consisting of 20 graphics primitives
# Max Adj Matrix EVal over Max Mult
# Graphics object consisting of 1 graphics primitive
# Max Lap Matrix EVal over Max Mult
# Graphics object consisting of 1 graphics primitive
# Max Distance Matrix EVal over Max Mult
# Graphics object consisting of 1 graphics primitive
# Max Degree over Max Mult
# Graphics object consisting of 1 graphics primitive
# Average Distance over Max Mult
# Graphics object consisting of 1 graphics primitive
# Average Distance over Max Distance Matrix EVal
# Graphics object consisting of 1 graphics primitive
# Smallest Distance with Max Mult over Max Mult
# Graphics object consisting of 1 graphics primitive
