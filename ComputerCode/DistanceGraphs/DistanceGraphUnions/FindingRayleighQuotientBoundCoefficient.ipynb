# %%
n = 13
k = 3
points = []
for T in graphs.trees(n):
    d = T.diameter()
    if d == 4:
        DD = T.distances_distribution()
        mult2 = DD[2]*n*(n-1)/2
        A = matrix(n,n)
        D = T.distance_matrix()
        for i in range(0,n):
            for j in range(0,n):
                if D[i][j] == k-2:
                    A[i,j] = 1
        H = Graph(A)
        maxDegH = max(H.degree_sequence())
        #show(H)
        Spec = H.spectrum()
        specRad = max(Spec)
        #show(H)
        #show(T)
        #show(specRad)
        multkMinus2 = DD[k-2]*n*(n-1)/2
        estimate = (mult2 + (n-1))*specRad
        multk = DD[k]*n*(n-1)/2
        points.append([multk, estimate])
        if (estimate/multk >10):
            show(T)
            print(estimate, multk)
        #if estimate/multk > 2:
            #show(T)
        #print(estimate/multk, specRad)
        #if estimate < multk-2 or estimate > multk + 2:
        #    print("failed case:")
        #    show(T)
        #    show(H)
        #    print("estimate: ", estimate, "mult(k): ", multk)
        #print("coeff: ", estimate)
        #show(A)
scatter_plot(points)
# Out:
# Graphics object consisting of 26 graphics primitives
# 187.7192869227216? 10
# Graphics object consisting of 26 graphics primitives
# 157.4001232308771? 10
# Graphics object consisting of 26 graphics primitives
# 134.8831871001610? 10
# Graphics object consisting of 26 graphics primitives
# 119.8078355398941? 10
# Graphics object consisting of 26 graphics primitives
# 113.76730637577740? 10
# Graphics object consisting of 26 graphics primitives
# 188.5877624883029? 18
# Graphics object consisting of 1 graphics primitive

# %%
n = 11
k = 5
for T in graphs.trees(n):
    if T.diameter() >= k:
        DD = T.distances_distribution()
        mult2 = DD[2]*n*(n-1)/2
        A = matrix(n,n)
        D = T.distance_matrix()
        for i in range(0,n):
            for j in range(0,n):
                if D[i][j] == k:
                    A[i,j] = 1
        H = Graph(A)
        #show(H)
        Spec = H.spectrum()
        specRad = max(Spec)
        #show(H)
        #show(T)
        #show(specRad)
        estimate = (2*mult2 + 2*(n-1))/specRad
        multk = DD[k]*n*(n-1)/2
        if estimate < multk-2 or estimate > multk + 2:
            print("failed case:")
            show(T)
            show(H)
            print("estimate: ", estimate, "mult(k): ", multk)
        #print("coeff: ", estimate)
        #show(A)
# Out:
# failed case:
# Graphics object consisting of 22 graphics primitives
# Graphics object consisting of 18 graphics primitives
# estimate:  26.87005768508881? mult(k):  6
# failed case:
# Graphics object consisting of 22 graphics primitives
# Graphics object consisting of 18 graphics primitives
# estimate:  28.28427124746190? mult(k):  6
# failed case:
# Graphics object consisting of 22 graphics primitives
# Graphics object consisting of 18 graphics primitives
# estimate:  28.28427124746190? mult(k):  6
# failed case:
# Graphics object consisting of 22 graphics primitives
# Graphics object consisting of 18 graphics primitives
# estimate:  28.28427124746190? mult(k):  6
# failed case:
# Graphics object consisting of 22 graphics primitives
# Graphics object consisting of 19 graphics primitives
# estimate:  23.09401076758503? mult(k):  7
# failed case:
# Graphics object consisting of 22 graphics primitives
# Graphics object consisting of 18 graphics primitives
# ...
